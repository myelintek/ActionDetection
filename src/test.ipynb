# %%
# Check Pytorch installation
import torch, torchvision

# Check MMAction2 installation
import mmaction

# Check MMCV installation
from mmcv.ops import get_compiling_cuda_version, get_compiler_version

# %%
path_to_video = "demo/demo.mp4"

# %%
# !python long_video_demo.py configs/recognition/tsn/tsn_r50_video_1x1x8_100e_kinetics400_rgb.py  checkpoints/tsn_r50_1x1x3_100e_kinetics400_rgb_20200614-e508be42.pth $path_to_video demo/label_map_k400.txt output_video.mp4  --input-step 3 --threshold 0.2
# Out:
# Use load_from_local loader
# [>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>] 280/280, 4.4 task/s, elapsed: 63s, ETA:     0s

# %% [markdown]
# # Show the results

# %%
import cv2
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline

cap = cv2.VideoCapture('output_video.mp4')

plt.rcParams["figure.figsize"] = (15, 15)
while(cap.isOpened()):
    try:
        ret, frame = cap.read()
        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        plt.imshow(frame)

        display.clear_output(wait=True)
        display.display(plt.gcf())

    except KeyboardInterrupt:
        cap.release()
